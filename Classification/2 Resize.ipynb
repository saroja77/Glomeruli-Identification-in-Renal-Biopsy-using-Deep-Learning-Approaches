# %%
from PIL import Image
import os

arr = os.listdir('/content/drive/MyDrive/glomeruli_segmentation/masks')
for i in arr:
  print(i)
  image = Image.open('/content/drive/MyDrive/glomeruli_segmentation/masks/'+i)
  new_image = image.resize((256,256))
  new_image.save('/content/drive/MyDrive/glomeruli_segmentation/masks/'+i)
# Out:
# normal_0396_imag_res_fill.png
# normal_0408_imag_res_fill.png
# normal_0403_imag_res_fill.png
# normal_0391_imag_res_fill.png
# normal_0393_imag_res_fill.png
# normal_0463_imag_res_fill.png
# normal_0411_imag_res_fill.png
# normal_0476_imag_res_fill.png
# normal_0455_imag_res_fill.png
# normal_0394_imag_res_fill.png
# normal_0407_imag_res_fill.png
# normal_0400_imag_res_fill.png
# normal_0462_imag_res_fill.png
# normal_0477_imag_res_fill.png
# normal_0480_imag_res_fill.png
# normal_0402_imag_res_fill.png
# normal_0429_imag_res_fill.png
# normal_0448_imag_res_fill.png
# normal_0438_imag_res_fill.png
# normal_0423_imag_res_fill.png
# normal_0365_imag_res_fill.png
# normal_0354_imag_res_fill.png
# normal_0680_imag_res_fill.png
# normal_0356_imag_res_fill.png
# normal_0350_imag_res_fill.png
# normal_0642_imag_res_fill.png
# normal_0374_imag_res_fill.png
# normal_0353_imag_res_fill.png
# normal_0368_imag_res_fill.png
# normal_0686_imag_res_fill.png
# normal_0657_imag_res_fill.png
# ...
